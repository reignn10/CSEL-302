# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset.csv', encoding = "latin -1")
data.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %%
plt.scatter(data['Travel_Time_to_School'],data['Grades'])
plt.xlabel ('Independent Variable (Travel_Time_To_School)')
plt.ylabel ('Dependent Variable (Grades)')
plt.title ('Scatter  Plot')
plt.show()

# %%
x = data[['Travel_Time_to_School']]
Y = data[['Grades']]

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]
intercept = model.intercept_
print ('Slope',slope)
print ('Intercept',intercept)
# Out:
# Slope [-0.09305324]
# Intercept [39.37929043]

# %%
plt.scatter(X,Y)
plt.plot(X, model.predict (X),color= 'red')
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Linear Regression')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_X = [[np.random.randint(100,200)]]

predict_Y = model.predict(new_X)

print('Value of X: ',new_X)
print ('Value of Y: ',new_Y)
# Out:
# Value of X:  [[153]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-252bcffb709f> in <cell line: 6>()
#       4
#       5 print('Value of X: ',new_X)
# ----> 6 print ('Value of Y: ',new_Y)
#
# NameError: name 'new_Y' is not defined
